# %% [markdown]
# # Pandas Package

# %% [markdown]
# Pandas deal with 3 data structures:
#
#     1) Series: 1D labelled homogeneous array
#                Size is immutable.
#                Values of data are mutable.
#
#     2)Dataframes: Hetregeneous data
#                   Size and values both are mutable.
#
#     3) Panel: 3d

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###  Series

# %%
ser = pd.Series(dtype=int)  # creates an empty series, by default it has float datatype
ser
# Out:
# Series([], dtype: int32)

# %%
l = [1,2,3,4]  # list
s=pd.Series(l)  #series
n = np.array(l)  # array
print("l: ",l)
print("s: ",s)
print("n: ",n)
# Out:
# l:  [1, 2, 3, 4]
# s:  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# n:  [1 2 3 4]

# %% [markdown]
# Thus, in a series the index of the elements are printed as well.

# %%
# from dictionary
data = {'a':0,'b':1,'c':3}
s=pd.Series(data)
s
# Out:
# a    0
# b    1
# c    3
# dtype: int64

# %%
# change the index of series
data = [1,2,3]
s=pd.Series(data,['g','h','k'])
s
# Out:
# g    1
# h    2
# k    3
# dtype: int64

# %% [markdown]
# ### Dataframes

# %% [markdown]
# To explore and handle 2-d data

# %%
df=pd.DataFrame(np.random.randn(5,3),index=['a','b','c','d','e'],columns=['one','two','three'])
df
# Out:
#         one       two     three
# a -1.362542 -1.183066  1.633129
# b  0.261664 -0.133808  0.071092
# c -0.477668 -1.800907 -1.099168
# d -2.441675  0.675044 -0.438707
# e  1.508571 -0.490636  0.534073

# %%
name=['Suganya','Tulasi','Pradeep','Bhargavi']
code=[23,45,92,56]
# representing it as a dataframe
df=pd.DataFrame(code,index=name,columns=['Code'])
df
# Out:
#           Code
# Suganya     23
# Tulasi      45
# Pradeep     92
# Bhargavi    56

# %% [markdown]
# ## Importing Dataset :
#     We have a dataset of airline safety in csv file

# %%
df = pd.read_csv("airline-safety.csv")
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %% [markdown]
# ## Handling Missing values:
#
# Handling missing values is very important before working on the dataset

# %% [markdown]
# The places where we have'NaN' are the missing values.

# %% [markdown]
# 1) Finding the missing values

# %%
# True wherever there is null value
df.isna()
# Out:
#     airline  avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# 0     False                   False            False                  False
# 1     False                   False            False                  False
# 2     False                   False            False                  False
# 3     False                   False            False                  False
# 4     False                   False             True                  False
# 5     False                   False            False                  False
# 6     False                   False            False                  False
# 7     False                   False            False                  False
# 8     False                   False            False                  False
# 9     False                   False            False                  False
# 10    False                   False             True                  False
# ...

# %%
# Counting missing value in every column
df.isna().sum()
# Out:
# airline                   0
# avail_seat_km_per_week    0
# incidents_85_99           2
# fatal_accidents_85_99     0
# fatalities_85_99          0
# incidents_00_14           2
# fatal_accidents_00_14     0
# fatalities_00_14          1
# dtype: int64

# %%
# Counting total null values:
df.isna().sum().sum()
# Out:
# 5

# %% [markdown]
# 2) Handling :
#     1. Drop the null values
#     2. Fill the null values

# %% [markdown]
# ### Drop:

# %%
# drops the entire row in which any null value is present
df2 = df.dropna()
df2
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734              2.0
# 1               Aeroflot*              1197672318             76.0
# 2   Aerolineas Argentinas               385803648              6.0
# 5              Air France              3004002661             14.0
# 6              Air India*               869253552              2.0
# 7        Air New Zealand*               710174817              3.0
# 9                Alitalia               698012498              7.0
# 11              American*              5228357340             21.0
# 12      Austrian Airlines               358239823              1.0
# 13                Avianca               396922563              5.0
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                       0                 0              0.0
# 1                      14               128              6.0
# ...

# %%
# drops the entire column in which any null value is present
df2=df.dropna(axis='columns')
df2
# Out:
#                   airline  avail_seat_km_per_week  fatal_accidents_85_99  \
# 0              Aer Lingus               320906734                      0
# 1               Aeroflot*              1197672318                     14
# 2   Aerolineas Argentinas               385803648                      0
# 3             Aeromexico*               596871813                      1
# 4              Air Canada              1865253802                      0
# 5              Air France              3004002661                      4
# 6              Air India*               869253552                      1
# 7        Air New Zealand*               710174817                      0
# 8        Alaska Airlines*               965346773                      0
# 9                Alitalia               698012498                      2
# 10     All Nippon Airways              1841234177                      1
# 11              American*              5228357340                      5
# ...

# %%
# deletes the row with atleast threshold non null values
df2=df.dropna(thresh=7)
df2
# the row with less than 7 non-null values will be deleted.
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734              2.0
# 1               Aeroflot*              1197672318             76.0
# 2   Aerolineas Argentinas               385803648              6.0
# 3             Aeromexico*               596871813              3.0
# 5              Air France              3004002661             14.0
# 6              Air India*               869253552              2.0
# 7        Air New Zealand*               710174817              3.0
# 8        Alaska Airlines*               965346773              5.0
# 9                Alitalia               698012498              7.0
# 10     All Nippon Airways              1841234177              NaN
# 11              American*              5228357340             21.0
# 12      Austrian Airlines               358239823              1.0
# 13                Avianca               396922563              5.0
#
# ...

# %%
# deletes entire row only if all the elements in the row are null
df2=df.dropna(how='all')
df2
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734              2.0
# 1               Aeroflot*              1197672318             76.0
# 2   Aerolineas Argentinas               385803648              6.0
# 3             Aeromexico*               596871813              3.0
# 4              Air Canada              1865253802              NaN
# 5              Air France              3004002661             14.0
# 6              Air India*               869253552              2.0
# 7        Air New Zealand*               710174817              3.0
# 8        Alaska Airlines*               965346773              5.0
# 9                Alitalia               698012498              7.0
# 10     All Nippon Airways              1841234177              NaN
# 11              American*              5228357340             21.0
# 12      Austrian Airlines               358239823              1.0
# ...

# %% [markdown]
# ### Filling:
#
#     Filling the null values requires domain knowledge.

# %% [markdown]
# There are three types:

# %% [markdown]
# ##### 1) Filling with mean, constant value or a string

# %%
df2= df.fillna(df.mean())
df2   ## The null values are filled by the mean value of that column
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734         2.000000
# 1               Aeroflot*              1197672318        76.000000
# 2   Aerolineas Argentinas               385803648         6.000000
# 3             Aeromexico*               596871813         3.000000
# 4              Air Canada              1865253802        12.083333
# 5              Air France              3004002661        14.000000
# 6              Air India*               869253552         2.000000
# 7        Air New Zealand*               710174817         3.000000
# 8        Alaska Airlines*               965346773         5.000000
# 9                Alitalia               698012498         7.000000
# 10     All Nippon Airways              1841234177        12.083333
# 11              American*              5228357340        21.000000
# 12      Austrian Airlines               358239823         1.000000
# ...

# %%
df2 =df.fillna('Missing value')
df2
# Out:
#                   airline  avail_seat_km_per_week incidents_85_99  \
# 0              Aer Lingus               320906734               2
# 1               Aeroflot*              1197672318              76
# 2   Aerolineas Argentinas               385803648               6
# 3             Aeromexico*               596871813               3
# 4              Air Canada              1865253802   Missing value
# 5              Air France              3004002661              14
# 6              Air India*               869253552               2
# 7        Air New Zealand*               710174817               3
# 8        Alaska Airlines*               965346773               5
# 9                Alitalia               698012498               7
# 10     All Nippon Airways              1841234177   Missing value
# 11              American*              5228357340              21
# 12      Austrian Airlines               358239823               1
# ...

# %% [markdown]
# ##### 2) Padding:
#
#      This has two types:
#
#             bfill/Backward filling- Fills the missing values with the values just below it.
#             ffill/Forward filling- Fills the missing values with the values above below it.(default)

# %%
# bfill :
df2=df.fillna(method='bfill')
df2
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734              2.0
# 1               Aeroflot*              1197672318             76.0
# 2   Aerolineas Argentinas               385803648              6.0
# 3             Aeromexico*               596871813              3.0
# 4              Air Canada              1865253802             14.0
# 5              Air France              3004002661             14.0
# 6              Air India*               869253552              2.0
# 7        Air New Zealand*               710174817              3.0
# 8        Alaska Airlines*               965346773              5.0
# 9                Alitalia               698012498              7.0
# 10     All Nippon Airways              1841234177             21.0
# 11              American*              5228357340             21.0
# 12      Austrian Airlines               358239823              1.0
# ...

# %%
# ffill :
df2=df.fillna(method='ffill')
df2
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734              2.0
# 1               Aeroflot*              1197672318             76.0
# 2   Aerolineas Argentinas               385803648              6.0
# 3             Aeromexico*               596871813              3.0
# 4              Air Canada              1865253802              3.0
# 5              Air France              3004002661             14.0
# 6              Air India*               869253552              2.0
# 7        Air New Zealand*               710174817              3.0
# 8        Alaska Airlines*               965346773              5.0
# 9                Alitalia               698012498              7.0
# 10     All Nippon Airways              1841234177              7.0
# 11              American*              5228357340             21.0
# 12      Austrian Airlines               358239823              1.0
# ...

# %% [markdown]
# This method may not work in some cases if the null value is in  first row in ffill or last row in bfill.

# %% [markdown]
# #### 3) Interpolates

# %% [markdown]
# This is a special dynamic method by pandas.
#
# We do not require domain knowledge in this case and it will choose dynamically the appropiate method and value.

# %%
df2=df.interpolate()
df2
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 0              Aer Lingus               320906734              2.0
# 1               Aeroflot*              1197672318             76.0
# 2   Aerolineas Argentinas               385803648              6.0
# 3             Aeromexico*               596871813              3.0
# 4              Air Canada              1865253802              8.5
# 5              Air France              3004002661             14.0
# 6              Air India*               869253552              2.0
# 7        Air New Zealand*               710174817              3.0
# 8        Alaska Airlines*               965346773              5.0
# 9                Alitalia               698012498              7.0
# 10     All Nippon Airways              1841234177             14.0
# 11              American*              5228357340             21.0
# 12      Austrian Airlines               358239823              1.0
# ...
